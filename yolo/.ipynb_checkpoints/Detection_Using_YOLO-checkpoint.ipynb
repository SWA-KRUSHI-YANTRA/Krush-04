# %%
conda install pytorch torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# Requirement already satisfied: gitpython in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 5)) (3.1.31)
# Requirement already satisfied: ipython in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (7.31.1)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (3.5.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (1.21.5)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (9.2.0)
# Requirement already satisfied: psutil in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 12)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 13)) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 14)) (1.9.1)
# Requirement already satisfied: thop>=0.1.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 15)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.7.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 16)) (1.13.1+cu117)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 17)) (0.14.1+cu117)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 18)) (4.64.1)
# Requirement already satisfied: tensorboard>=2.4.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 22)) (2.11.2)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 27)) (1.4.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 28)) (0.11.2)
# Requirement already satisfied: setuptools>=65.5.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 42)) (67.4.0)
# Requirement already satisfied: wheel>=0.38.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from -r requirements.txt (line 43)) (0.38.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from gitpython->-r requirements.txt (line 5)) (4.0.10)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 6)) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 6)) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: colorama in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 6)) (0.4.5)
# Requirement already satisfied: pygments in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 6)) (2.11.2)
# Requirement already satisfied: backcall in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: decorator in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from ipython->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (2.0.4)
# Requirement already satisfied: typing-extensions in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from torch>=1.7.0->-r requirements.txt (line 16)) (4.3.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.51.3)
# Requirement already satisfied: protobuf<4,>=3.9.2 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (3.19.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (2.16.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.4.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (3.3.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2022.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->-r requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 6)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r requirements.txt (line 6)) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\atharva_nimbalkar\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 22)) (3.2.2)

# %%
import torch
import numpy as np
import cv2

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['cotton']
number_imgs = 1903

# %%
import os
import uuid

# Path to the folder containing the images
# folder_path = "/path/to/folder"

# Get a list of all files in the folder
file_list = os.listdir(IMAGES_PATH)

# Loop through each file and rename it to a unique identifier
for file_name in file_list:
    # Only rename files that are images
    if file_name.endswith(".jpg") or file_name.endswith(".png") or file_name.endswith(".jpeg"):
        # Generate a new file name using a UUID
        new_file_name = 'cotton.'+str(uuid.uuid4()) + os.path.splitext(file_name)[1]
        # Build the full path to the file
        old_file_path = os.path.join(IMAGES_PATH, file_name)
        new_file_path = os.path.join(IMAGES_PATH, new_file_name)
        # Rename the file
        os.rename(old_file_path, new_file_path)

# %%
# !git clone https://github.com/tzutalin/labelImg

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2

# %%
# !pip list

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# []
